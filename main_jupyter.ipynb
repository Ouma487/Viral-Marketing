# %%
from extract_data import *
from utility import *
from extract_data import *
from affichage import *
from plot import *
from strategie import *
from propagation import *
from generation import *

# %%
path = "data/"

df_accounts = pd.read_csv(path+"instagram_accounts.csv")
df_posts = pd.read_csv(path+"instagram_post_9-11_16-11.csv")

# %%
plot_like_follower()

# %%
plot_like_date()

# %%
plot_like_time()

# %%
plot_like_views()

# %%
plot_histo_likes()

# %%
plot_histo_follow_user()

# %%
plot_histo_follo()

# %%
plot_histo_like_follower()
# Out:
# 93
# 4
# 77
# 0
# 8
# 2
# 14
# 9
# 35
# 7
# 41
# 42
# 69
# 11
# 29
# 22
# 14
# 17
# 4
# 44
# 108
# 13
# 26
# 1
# 3
# 1
# 12
# 4
# 17
# 18
# 3
# 12
# 15
# 41
# 24
# 14
# 4
# 5
# 32
# 1
# 5
# 3
# 48
# 6
# 27
# 33
# 9
# 81
# 34
# 23
# 5
# 10
# 35
# 8
# 76
# 20
# 4
# 0
# 10
# 3
# 27
# 19
# 11
# 1
# 30
# 89
# 6
# 0
# 35
# 49
# 14
# 3
# 22
# 12
# 3
# 26
# 22
# 32
# 2
# 32
# 17
# 37
# 9
# 68
# 28
# 14
# 0
# 1
# 7
# 36
# 26
# 65
# 1
# 19
# 0
# 18
# 1
# 23
# 23
# 10
# 33
# 17
# 13
# 53
# 3
# 47
# 26
# 8
# 2
# 9
# 11
# 30
# 54
# 53
# 14
# 0
# 43
# 4
# 12
# 7
# 53
# 0
# 9
# 16
# 25
# 7
# 9
# 39
# 34
# 53
# 17
# 35
# 5
# 16
# 22
# 18
# 12
# 81
# 2
# 56
# 28
# 2
# 4
# 48
# 8
# 36
# 7
# 12
# 43
# 15
# 2
# 106
# 51
# 49
# 3
# 16
# 40
# 80
# 11
# 0
# 19
# 32
# 0
# 5
# 2
# 4
# 4
# 19
# 9
# 62
# 5
# 28
# 22
# 16
# 3
# 0
# 12
# 17
# 17
# 25
# 14
# 2
# 1
# 0
# 19
# 22
# 3
# 3
# 8
# 7
# 29
# 3
# 20
# 4
# 4
# 2
# 41
# 0
# 26
# 48
# 75
# 33
# 48
# 7
# 4
# 20
# 13
# 20
# 5
# 14
# 0
# 15
# 43
# 32
# 4
# 45
# ...

# %%
vertex, edges = graph()
#afficher_graph(vertex, edges)

# %%
new_vertex, new_edges = limiter_graph(vertex, edges, 100)
afficher_graph(new_vertex, new_edges, nom='nb', color=True)

# %%
strategie = random_post(vertex, edges, p=0.001)
tps, nb_like, nb_personne_like, nb_personne_repost = propagation(vertex, edges, strategie, time=20)
afficher_propagation(tps, nb_like, nb_personne_like, nb_personne_repost)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:title={'center':'Nombre de like en fonction du temps'}>,
#          <AxesSubplot:title={'center':'Nombre de personne qui like'}>],
#         [<AxesSubplot:title={'center':'Nombre de personne qui repost'}>,
#          <AxesSubplot:>]], dtype=object))

# %%
strategie = best_influenceurs(vertex, edges, nb=5)
tps, nb_like, nb_personne_like, nb_personne_repost = propagation(vertex, edges, strategie, time=20)
afficher_propagation(tps, nb_like, nb_personne_like, nb_personne_repost)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:title={'center':'Nombre de like en fonction du temps'}>,
#          <AxesSubplot:title={'center':'Nombre de personne qui like'}>],
#         [<AxesSubplot:title={'center':'Nombre de personne qui repost'}>,
#          <AxesSubplot:>]], dtype=object))

# %%
#evaluation_strategie()

# %%
vertex, edges = graphe_aléatoire_powerlaw(3046)

# %%
proba_dessin(vertex, edges, pas=1)

# %%
nv, ne = limiter_graph(vertex, edges, 200)
afficher_graph(nv, ne, nom='user', color=True)

# %%
strategie = random_post(vertex, edges, p=0.001)
tps, nb_like, nb_personne_like, nb_personne_repost = propagation(vertex, edges, strategie, time=50)
afficher_propagation(tps, nb_like, nb_personne_like, nb_personne_repost)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:title={'center':'Nombre de like en fonction du temps'}>,
#          <AxesSubplot:title={'center':'Nombre de personne qui like'}>],
#         [<AxesSubplot:title={'center':'Nombre de personne qui repost'}>,
#          <AxesSubplot:>]], dtype=object))

# %%
strategie = best_influenceurs(vertex, edges, nb=5)
tps, nb_like, nb_personne_like, nb_personne_repost = propagation(vertex, edges, strategie, time=50)
afficher_propagation(tps, nb_like, nb_personne_like, nb_personne_repost)
# Out:
# (<Figure size 432x288 with 4 Axes>,
#  array([[<AxesSubplot:title={'center':'Nombre de like en fonction du temps'}>,
#          <AxesSubplot:title={'center':'Nombre de personne qui like'}>],
#         [<AxesSubplot:title={'center':'Nombre de personne qui repost'}>,
#          <AxesSubplot:>]], dtype=object))
